# %%
import matplotlib.pyplot as plt
import numpy as np


b = 0.1  #kg/m
g= 9.8 #m/s^2
m = 1 #kg
v0 =0 #velocidade inicial
h= 0.1 #passos 

def Queda_resistencia(v):
    return -g -b/m *v

t= np.arange(0, 100 , h)
v = np.zeros(len(t))

v[0] = v0

for i in range(1, len(t)):
    v[i] = v[i-1] + h*Queda_resistencia(v[i-1])
    
for i in range(len(t) -1):
    print(f't = {t[i]} , v = {v[i]}')

velocidade_terminal = (-m*g )/ b

vel_terminal_line = [velocidade_terminal] * len(t)

plt.plot(t , v)
plt.plot(t, vel_terminal_line, label=f'Velocidade terminal = {velocidade_terminal:.2f} m/s', color='red', linestyle='--')
plt.xlabel('t(s)')
plt.ylabel('v (m/s)')
plt.tight_layout()
plt.title('Queda livre com resistencia do ar')
plt.legend()
plt.show()
# Out:
# t = 0.0 , v = 0.0
# t = 0.1 , v = -0.9800000000000001
# t = 0.2 , v = -1.9502000000000002
# t = 0.30000000000000004 , v = -2.9106980000000005
# t = 0.4 , v = -3.8615910200000005
# t = 0.5 , v = -4.8029751098
# t = 0.6000000000000001 , v = -5.734945358702
# t = 0.7000000000000001 , v = -6.657595905114981
# t = 0.8 , v = -7.571019946063831
# t = 0.9 , v = -8.475309746603193
# t = 1.0 , v = -9.37055664913716
# t = 1.1 , v = -10.256851082645788
# t = 1.2000000000000002 , v = -11.13428257181933
# t = 1.3 , v = -12.002939746101138
# t = 1.4000000000000001 , v = -12.862910348640126
# t = 1.5 , v = -13.714281245153725
# t = 1.6 , v = -14.557138432702187
# t = 1.7000000000000002 , v = -15.391567048375165
# t = 1.8 , v = -16.217651377891414
# t = 1.9000000000000001 , v = -17.0354748641125
# t = 2.0 , v = -17.845120115471378
# t = 2.1 , v = -18.646668914316663
# t = 2.2 , v = -19.440202225173497
# t = 2.3000000000000003 , v = -20.22580020292176
# ...
